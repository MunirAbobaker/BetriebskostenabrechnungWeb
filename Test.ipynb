# %% [markdown]
# <a href="https://colab.research.google.com/github/MunirAbobaker/BetriebskostenabrechnungWeb/blob/master/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("drive/MyDrive/Data Science/immo_data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-662066a83fd3> in <module>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("drive/MyDrive/Data Science/immo_data.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
# ...

# %%
df.shape
# Out:
# (268850, 49)

# %%
df.columns
# Out:
# Index(['regio1', 'serviceCharge', 'heatingType', 'telekomTvOffer',
#        'telekomHybridUploadSpeed', 'newlyConst', 'balcony', 'picturecount',
#        'pricetrend', 'telekomUploadSpeed', 'totalRent', 'yearConstructed',
#        'scoutId', 'noParkSpaces', 'firingTypes', 'hasKitchen', 'geo_bln',
#        'cellar', 'yearConstructedRange', 'baseRent', 'houseNumber',
#        'livingSpace', 'geo_krs', 'condition', 'interiorQual', 'petsAllowed',
#        'street', 'streetPlain', 'lift', 'baseRentRange', 'typeOfFlat',
#        'geo_plz', 'noRooms', 'thermalChar', 'floor', 'numberOfFloors',
#        'noRoomsRange', 'garden', 'livingSpaceRange', 'regio2', 'regio3',
#        'description', 'facilities', 'heatingCosts', 'energyEfficiencyClass',
#        'lastRefurbish', 'electricityBasePrice', 'electricityKwhPrice', 'date'],
#       dtype='object')

# %%
df.isna()
# Out:
#         regio1  serviceCharge  ...  electricityKwhPrice   date
# 0        False          False  ...                 True  False
# 1        False          False  ...                 True  False
# 2        False          False  ...                 True  False
# 3        False          False  ...                 True  False
# 4        False          False  ...                 True  False
# ...        ...            ...  ...                  ...    ...
# 268845   False          False  ...                 True  False
# 268846   False          False  ...                 True  False
# 268847   False          False  ...                 True  False
# 268848   False          False  ...                 True  False
# 268849   False          False  ...                 True  False
#
# [268850 rows x 49 columns]

# %%
df.tail()
# Out:
#                      regio1  serviceCharge  ... electricityKwhPrice   date
# 268845               Bayern           90.0  ...                 NaN  Feb20
# 268846               Hessen          220.0  ...                 NaN  May19
# 268847               Hessen          220.0  ...                 NaN  Feb20
# 268848  Nordrhein_Westfalen          175.0  ...                 NaN  May19
# 268849               Hessen          315.0  ...                 NaN  Feb20
#
# [5 rows x 49 columns]

# %%
clean_df = df.dropna()

# %%
clean_df.tail()
# Out:
#                      regio1  serviceCharge  ... electricityKwhPrice   date
# 243055               Hessen         133.00  ...              0.1985  Sep18
# 255641  Nordrhein_Westfalen         160.00  ...              0.1915  Sep18
# 257203      Rheinland_Pfalz         180.00  ...              0.1915  Sep18
# 258585              Sachsen          70.00  ...              0.1985  Sep18
# 268840               Hessen         112.13  ...              0.1985  Sep18
#
# [5 rows x 49 columns]

# %%
clean_df.totalRent.idxmax()
# Out:
# 212447

# %%
clean_df.totalRent.loc[212447]
# Out:
# 2300.0

# %%
clean_data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-1353ed04c52d> in <module>()
# ----> 1 clean_data.info()
#
# NameError: name 'clean_data' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   regio1                    268850 non-null  object
#  1   serviceCharge             261941 non-null  float64
#  2   heatingType               223994 non-null  object
#  3   telekomTvOffer            236231 non-null  object
#  4   telekomHybridUploadSpeed  45020 non-null   float64
#  5   newlyConst                268850 non-null  bool
#  6   balcony                   268850 non-null  bool
#  7   picturecount              268850 non-null  int64
#  8   pricetrend                267018 non-null  float64
#  9   telekomUploadSpeed        235492 non-null  float64
#  10  totalRent                 228333 non-null  float64
#  11  yearConstructed           211805 non-null  float64
#  12  scoutId                   268850 non-null  int64
# ...

# %%
df.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-be0d78cbcf9f> in <module>()
# ----> 1 df.values
#
# NameError: name 'df' is not defined

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (268850, 49)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   regio1                    268850 non-null  object
#  1   serviceCharge             261941 non-null  float64
#  2   heatingType               223994 non-null  object
#  3   telekomTvOffer            236231 non-null  object
#  4   telekomHybridUploadSpeed  45020 non-null   float64
#  5   newlyConst                268850 non-null  bool
#  6   balcony                   268850 non-null  bool
#  7   picturecount              268850 non-null  int64
#  8   pricetrend                267018 non-null  float64
#  9   telekomUploadSpeed        235492 non-null  float64
#  10  totalRent                 228333 non-null  float64
#  11  yearConstructed           211805 non-null  float64
#  12  scoutId                   268850 non-null  int64
# ...

# %%
df['date']
# Out:
# 0         May19
# 1         May19
# 2         Oct19
# 3         May19
# 4         Feb20
#           ...
# 268845    Feb20
# 268846    May19
# 268847    Feb20
# 268848    May19
# 268849    Feb20
# Name: date, Length: 268850, dtype: object

# %%
date_df = ['date']

# %%
type(date_df)
# Out:
# list

# %%
subset = df[['date', 'electricityKwhPrice']]

# %%
subset.head()
# Out:
#     date  electricityKwhPrice
# 0  May19                  NaN
# 1  May19                  NaN
# 2  Oct19                  NaN
# 3  May19                  NaN
# 4  Feb20                  NaN

# %%
pandas.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-068244f7ed4b> in <module>()
# ----> 1 pandas.__version__
#
# NameError: name 'pandas' is not defined

# %%
pd.__version__
# Out:
# '1.1.5'
